# %%
import torch
from torch import nn
import numpy as np
from stacked_mnist import StackedMNISTData, DataMode
from tensorflow import keras

# %%
class Encoder(nn.Module):
    def __init__(self, encoded_space_dim, fc2_input_dim):
        super().__init__()

        ### Convolutional section
        self.encoder_cnn = nn.Sequential(
            # First convolutional layer
            nn.Conv2d(1, 8, 3, stride=2, padding=1),
            # nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Second convolutional layer
            nn.Conv2d(8, 16, 3, stride=2, padding=1),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Third convolutional layer
            nn.Conv2d(16, 32, 3, stride=2, padding=0),
            # nn.BatchNorm2d(32),
            nn.ReLU(True),
        )

        ### Flatten layer
        self.flatten = nn.Flatten(start_dim=1)

        ### Linear section
        self.encoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(3 * 3 * 32, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, encoded_space_dim),
        )

    def forward(self, x):
        # Apply convolutions
        x = self.encoder_cnn(x)
        # Flatten
        x = self.flatten(x)
        # # Apply linear layers
        x = self.encoder_lin(x)
        return x

# %%
class Decoder(nn.Module):
    
    def __init__(self, encoded_space_dim,fc2_input_dim):
        super().__init__()

        ### Linear section
        self.decoder_lin = nn.Sequential(
            # First linear layer
            nn.Linear(encoded_space_dim, 128),
            nn.ReLU(True),
            # Second linear layer
            nn.Linear(128, 3 * 3 * 32),
            nn.ReLU(True)
        )

        ### Unflatten
        self.unflatten = nn.Unflatten(dim=1, unflattened_size=(32, 3, 3))

        ### Convolutional section
        self.decoder_conv = nn.Sequential(
            # First transposed convolution
            nn.ConvTranspose2d(32, 16, 3, stride=2, output_padding=0),
            nn.BatchNorm2d(16),
            nn.ReLU(True),
            # Second transposed convolution
            nn.ConvTranspose2d(16, 8, 3, stride=2, padding=1, output_padding=1),
            nn.BatchNorm2d(8),
            nn.ReLU(True),
            # Third transposed convolution
            nn.ConvTranspose2d(8, 1, 3, stride=2, padding=1, output_padding=1)
        )
        
    def forward(self, x):
        # Apply linear layers
        x = self.decoder_lin(x)
        # Unflatten
        x = self.unflatten(x)
        # Apply transposed convolutions
        x = self.decoder_conv(x)
        # Apply a sigmoid to force the output to be between 0 and 1 (valid pixel values)
        x = torch.sigmoid(x)
        return x

# %%
d = 8
encoder = Encoder(encoded_space_dim=d,fc2_input_dim=128)
decoder = Decoder(encoded_space_dim=d,fc2_input_dim=128)

# %%
loss_fn = torch.nn.MSELoss()
lr= 0.001
params_to_optimize = [
    {'params': encoder.parameters()},
    {'params': decoder.parameters()}
]
optim = torch.optim.Adam(params_to_optimize, lr=lr, weight_decay=1e-05)

# %%
### Training function
def train_epoch(encoder, decoder, loss_fn, optimizer, x):
    # Set train mode for both the encoder and the decoder
    encoder.train()
    decoder.train()
    train_loss = []

    # Encode data
    encoded_data = encoder(x)
    # Decode data
    decoded_data = decoder(encoded_data)
    # Evaluate loss
    loss = loss_fn(decoded_data, x)
    # Backward pass
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # Print batch loss
    print('\t partial train loss (single batch): %f' % (loss.data))
    train_loss.append(loss.detach().numpy())

    return train_loss

# %%
### Testing function
def test_epoch(encoder, decoder, loss_fn, x):
    # Set evaluation mode for encoder and decoder
    encoder.eval()
    decoder.eval()
    with torch.no_grad(): # No need to track the gradients
        # Define the lists to store the outputs for each batch
        conc_out = []
        conc_label = []
        # Encode data
        encoded_data = encoder(x)
        # Decode data
        decoded_data = decoder(encoded_data)
        # Append the network output and the original image to the lists
        conc_out.append(decoded_data)
        conc_label.append(x)
        # Create a single tensor with all the values in the lists
        conc_out = torch.cat(conc_out)
        conc_label = torch.cat(conc_label) 
        # Evaluate global loss
        val_loss = loss_fn(conc_out, conc_label)
    return val_loss.data

# %%
generator = StackedMNISTData(mode=DataMode.MONO_BINARY_COMPLETE)

# %%
import matplotlib.pyplot as plt
import random 
num_epochs = 3500
history={'train_loss':[],'val_loss':[]}
for epoch in range(num_epochs):
   img_train, labels_train = generator.get_random_batch(training=True)
   img_test, labels_test = generator.get_random_batch(training=False)
   img_train = np.swapaxes(img_train, 2, 3)
   img_train = np.swapaxes(img_train, 1, 2)
   img_test = np.swapaxes(img_test, 2, 3)
   img_test = np.swapaxes(img_test, 1, 2)
   #img = img_train[0]
   #plt.imshow(np.array(img).reshape((28, 28)))


   img_train = torch.tensor(img_train)
   img_train = img_train.type(torch.FloatTensor)
   img_test = torch.tensor(img_test)
   img_test = img_test.type(torch.FloatTensor)
   train_loss = train_epoch(encoder,decoder,loss_fn,optim, img_train)
   val_loss = test_epoch(encoder,decoder,loss_fn, img_test)
   print(f"Epoch {epoch+1}/{num_epochs} train loss: {train_loss}, val loss: {val_loss}")
   #print('\n EPOCH {}/{} \t train loss {:.3f} \t val loss {:.3f}'.format(epoch + 1, num_epochs,train_loss,val_loss))
   history['train_loss'].append(train_loss)
   history['val_loss'].append(val_loss)
# Out:
# 	 partial train loss (single batch): 0.228156
# Epoch 1/3500 train loss: [array(0.2281561, dtype=float32)], val loss: 0.22494269907474518
# 	 partial train loss (single batch): 0.222119
# Epoch 2/3500 train loss: [array(0.22211887, dtype=float32)], val loss: 0.22508504986763
# 	 partial train loss (single batch): 0.217666
# Epoch 3/3500 train loss: [array(0.21766569, dtype=float32)], val loss: 0.22480206191539764
# 	 partial train loss (single batch): 0.212308
# Epoch 4/3500 train loss: [array(0.21230753, dtype=float32)], val loss: 0.22440338134765625
# 	 partial train loss (single batch): 0.208540
# Epoch 5/3500 train loss: [array(0.20853986, dtype=float32)], val loss: 0.22389645874500275
# 	 partial train loss (single batch): 0.205306
# Epoch 6/3500 train loss: [array(0.20530626, dtype=float32)], val loss: 0.22317802906036377
# 	 partial train loss (single batch): 0.202265
# Epoch 7/3500 train loss: [array(0.20226528, dtype=float32)], val loss: 0.22261008620262146
# 	 partial train loss (single batch): 0.198582
# Epoch 8/3500 train loss: [array(0.19858196, dtype=float32)], val loss: 0.22256875038146973
# 	 partial train loss (single batch): 0.197393
# Epoch 9/3500 train loss: [array(0.19739306, dtype=float32)], val loss: 0.221575528383255
# 	 partial train loss (single batch): 0.193629
# Epoch 10/3500 train loss: [array(0.19362889, dtype=float32)], val loss: 0.2209370732307434
# 	 partial train loss (single batch): 0.192320
# Epoch 11/3500 train loss: [array(0.19232005, dtype=float32)], val loss: 0.22012560069561005
# 	 partial train loss (single batch): 0.189422
# Epoch 12/3500 train loss: [array(0.18942197, dtype=float32)], val loss: 0.2195136994123459
# 	 partial train loss (single batch): 0.187130
# Epoch 13/3500 train loss: [array(0.18712951, dtype=float32)], val loss: 0.21835848689079285
# 	 partial train loss (single batch): 0.184787
# Epoch 14/3500 train loss: [array(0.18478656, dtype=float32)], val loss: 0.2174224704504013
# 	 partial train loss (single batch): 0.183679
# Epoch 15/3500 train loss: [array(0.18367927, dtype=float32)], val loss: 0.21682588756084442
# 	 partial train loss (single batch): 0.181066
# Epoch 16/3500 train loss: [array(0.18106563, dtype=float32)], val loss: 0.21523229777812958
# 	 partial train loss (single batch): 0.179488
# Epoch 17/3500 train loss: [array(0.17948772, dtype=float32)], val loss: 0.21491488814353943
# 	 partial train loss (single batch): 0.177648
# Epoch 18/3500 train loss: [array(0.17764789, dtype=float32)], val loss: 0.21325334906578064
# 	 partial train loss (single batch): 0.176338
# Epoch 19/3500 train loss: [array(0.17633808, dtype=float32)], val loss: 0.21146371960639954
# 	 partial train loss (single batch): 0.173888
# Epoch 20/3500 train loss: [array(0.1738877, dtype=float32)], val loss: 0.21079976856708527
# 	 partial train loss (single batch): 0.172406
# Epoch 21/3500 train loss: [array(0.17240599, dtype=float32)], val loss: 0.20861504971981049
# 	 partial train loss (single batch): 0.170233
# Epoch 22/3500 train loss: [array(0.17023346, dtype=float32)], val loss: 0.20789572596549988
# 	 partial train loss (single batch): 0.169554
# Epoch 23/3500 train loss: [array(0.16955444, dtype=float32)], val loss: 0.2054470181465149
# 	 partial train loss (single batch): 0.167086
# Epoch 24/3500 train loss: [array(0.16708642, dtype=float32)], val loss: 0.2044428586959839
# 	 partial train loss (single batch): 0.165797
# Epoch 25/3500 train loss: [array(0.1657973, dtype=float32)], val loss: 0.20349286496639252
# 	 partial train loss (single batch): 0.164103
# Epoch 26/3500 train loss: [array(0.16410308, dtype=float32)], val loss: 0.20149998366832733
# 	 partial train loss (single batch): 0.163007
# Epoch 27/3500 train loss: [array(0.16300677, dtype=float32)], val loss: 0.19997099041938782
# 	 partial train loss (single batch): 0.161665
# Epoch 28/3500 train loss: [array(0.16166537, dtype=float32)], val loss: 0.19850189983844757
# 	 partial train loss (single batch): 0.159697
# Epoch 29/3500 train loss: [array(0.15969688, dtype=float32)], val loss: 0.19639481604099274
# 	 partial train loss (single batch): 0.158395
# Epoch 30/3500 train loss: [array(0.15839507, dtype=float32)], val loss: 0.1949690580368042
# 	 partial train loss (single batch): 0.157071
# Epoch 31/3500 train loss: [array(0.15707074, dtype=float32)], val loss: 0.19407355785369873
# 	 partial train loss (single batch): 0.155396
# Epoch 32/3500 train loss: [array(0.15539564, dtype=float32)], val loss: 0.19190764427185059
# 	 partial train loss (single batch): 0.155023
# Epoch 33/3500 train loss: [array(0.1550234, dtype=float32)], val loss: 0.18977701663970947
# 	 partial train loss (single batch): 0.153259
# Epoch 34/3500 train loss: [array(0.15325934, dtype=float32)], val loss: 0.18854010105133057
# 	 partial train loss (single batch): 0.151876
# Epoch 35/3500 train loss: [array(0.15187597, dtype=float32)], val loss: 0.18728922307491302
# 	 partial train loss (single batch): 0.150076
# Epoch 36/3500 train loss: [array(0.15007561, dtype=float32)], val loss: 0.1857774257659912
# 	 partial train loss (single batch): 0.148660
# Epoch 37/3500 train loss: [array(0.14866045, dtype=float32)], val loss: 0.18425114452838898
# 	 partial train loss (single batch): 0.147334
# Epoch 38/3500 train loss: [array(0.14733383, dtype=float32)], val loss: 0.18196004629135132
# 	 partial train loss (single batch): 0.145721
# Epoch 39/3500 train loss: [array(0.14572075, dtype=float32)], val loss: 0.18045736849308014
# 	 partial train loss (single batch): 0.145815
# Epoch 40/3500 train loss: [array(0.14581485, dtype=float32)], val loss: 0.1776065081357956
# 	 partial train loss (single batch): 0.143015
# Epoch 41/3500 train loss: [array(0.14301464, dtype=float32)], val loss: 0.17622680962085724
# 	 partial train loss (single batch): 0.143949
# Epoch 42/3500 train loss: [array(0.14394929, dtype=float32)], val loss: 0.17401497066020966
# 	 partial train loss (single batch): 0.142500
# Epoch 43/3500 train loss: [array(0.1425001, dtype=float32)], val loss: 0.17279867827892303
# 	 partial train loss (single batch): 0.141466
# Epoch 44/3500 train loss: [array(0.14146598, dtype=float32)], val loss: 0.17190788686275482
# 	 partial train loss (single batch): 0.140488
# Epoch 45/3500 train loss: [array(0.1404876, dtype=float32)], val loss: 0.1680736541748047
# 	 partial train loss (single batch): 0.139307
# Epoch 46/3500 train loss: [array(0.13930675, dtype=float32)], val loss: 0.16749818623065948
# 	 partial train loss (single batch): 0.138321
# Epoch 47/3500 train loss: [array(0.13832098, dtype=float32)], val loss: 0.16525298357009888
# 	 partial train loss (single batch): 0.135412
# Epoch 48/3500 train loss: [array(0.13541184, dtype=float32)], val loss: 0.16363027691841125
# 	 partial train loss (single batch): 0.135664
# Epoch 49/3500 train loss: [array(0.1356637, dtype=float32)], val loss: 0.16066984832286835
# 	 partial train loss (single batch): 0.134799
# Epoch 50/3500 train loss: [array(0.13479903, dtype=float32)], val loss: 0.15937088429927826
# 	 partial train loss (single batch): 0.133106
# Epoch 51/3500 train loss: [array(0.1331059, dtype=float32)], val loss: 0.1571091115474701
# 	 partial train loss (single batch): 0.131947
# Epoch 52/3500 train loss: [array(0.13194706, dtype=float32)], val loss: 0.15594008564949036
# 	 partial train loss (single batch): 0.132054
# Epoch 53/3500 train loss: [array(0.13205405, dtype=float32)], val loss: 0.15363727509975433
# 	 partial train loss (single batch): 0.130024
# Epoch 54/3500 train loss: [array(0.13002446, dtype=float32)], val loss: 0.15098093450069427
# 	 partial train loss (single batch): 0.129113
# Epoch 55/3500 train loss: [array(0.12911278, dtype=float32)], val loss: 0.14969639480113983
# 	 partial train loss (single batch): 0.127516
# Epoch 56/3500 train loss: [array(0.12751637, dtype=float32)], val loss: 0.14674395322799683
# 	 partial train loss (single batch): 0.126974
# Epoch 57/3500 train loss: [array(0.12697406, dtype=float32)], val loss: 0.14430800080299377
# 	 partial train loss (single batch): 0.125962
# Epoch 58/3500 train loss: [array(0.12596199, dtype=float32)], val loss: 0.14249037206172943
# 	 partial train loss (single batch): 0.124426
# Epoch 59/3500 train loss: [array(0.12442608, dtype=float32)], val loss: 0.1395610272884369
# 	 partial train loss (single batch): 0.123278
# Epoch 60/3500 train loss: [array(0.12327778, dtype=float32)], val loss: 0.1373344212770462
# 	 partial train loss (single batch): 0.122947
# Epoch 61/3500 train loss: [array(0.1229467, dtype=float32)], val loss: 0.13762229681015015
# 	 partial train loss (single batch): 0.121071
# Epoch 62/3500 train loss: [array(0.12107054, dtype=float32)], val loss: 0.13498537242412567
# 	 partial train loss (single batch): 0.121243
# Epoch 63/3500 train loss: [array(0.1212433, dtype=float32)], val loss: 0.13399314880371094
# 	 partial train loss (single batch): 0.120512
# Epoch 64/3500 train loss: [array(0.12051183, dtype=float32)], val loss: 0.1312538981437683
# 	 partial train loss (single batch): 0.119499
# Epoch 65/3500 train loss: [array(0.11949895, dtype=float32)], val loss: 0.12876814603805542
# 	 partial train loss (single batch): 0.120319
# Epoch 66/3500 train loss: [array(0.12031926, dtype=float32)], val loss: 0.12666887044906616
# 	 partial train loss (single batch): 0.116658
# Epoch 67/3500 train loss: [array(0.11665819, dtype=float32)], val loss: 0.12599387764930725
# 	 partial train loss (single batch): 0.117265
# Epoch 68/3500 train loss: [array(0.11726468, dtype=float32)], val loss: 0.12316608428955078
# 	 partial train loss (single batch): 0.114550
# Epoch 69/3500 train loss: [array(0.11455049, dtype=float32)], val loss: 0.12219229340553284
# 	 partial train loss (single batch): 0.114771
# Epoch 70/3500 train loss: [array(0.1147713, dtype=float32)], val loss: 0.119040846824646
# 	 partial train loss (single batch): 0.115267
# Epoch 71/3500 train loss: [array(0.11526748, dtype=float32)], val loss: 0.1180911585688591
# 	 partial train loss (single batch): 0.113772
# Epoch 72/3500 train loss: [array(0.11377232, dtype=float32)], val loss: 0.11705417186021805
# 	 partial train loss (single batch): 0.112745
# Epoch 73/3500 train loss: [array(0.11274466, dtype=float32)], val loss: 0.11504755169153214
# 	 partial train loss (single batch): 0.111358
# Epoch 74/3500 train loss: [array(0.11135756, dtype=float32)], val loss: 0.11490760743618011
# 	 partial train loss (single batch): 0.110664
# Epoch 75/3500 train loss: [array(0.11066384, dtype=float32)], val loss: 0.11141332983970642
# 	 partial train loss (single batch): 0.111374
# Epoch 76/3500 train loss: [array(0.11137389, dtype=float32)], val loss: 0.11139503121376038
# 	 partial train loss (single batch): 0.110096
# Epoch 77/3500 train loss: [array(0.11009624, dtype=float32)], val loss: 0.10918877273797989
# 	 partial train loss (single batch): 0.108881
# Epoch 78/3500 train loss: [array(0.1088808, dtype=float32)], val loss: 0.10913387686014175
# 	 partial train loss (single batch): 0.108722
# Epoch 79/3500 train loss: [array(0.10872208, dtype=float32)], val loss: 0.10613218694925308
# 	 partial train loss (single batch): 0.106123
# Epoch 80/3500 train loss: [array(0.10612288, dtype=float32)], val loss: 0.10751648992300034
# 	 partial train loss (single batch): 0.106591
# Epoch 81/3500 train loss: [array(0.10659077, dtype=float32)], val loss: 0.10515058040618896
# 	 partial train loss (single batch): 0.105329
# Epoch 82/3500 train loss: [array(0.1053292, dtype=float32)], val loss: 0.10659679025411606
# 	 partial train loss (single batch): 0.105103
# Epoch 83/3500 train loss: [array(0.10510278, dtype=float32)], val loss: 0.10407143831253052
# 	 partial train loss (single batch): 0.103686
# Epoch 84/3500 train loss: [array(0.10368638, dtype=float32)], val loss: 0.10301774740219116
# 	 partial train loss (single batch): 0.103026
# Epoch 85/3500 train loss: [array(0.10302634, dtype=float32)], val loss: 0.1023860052227974
# 	 partial train loss (single batch): 0.103261
# Epoch 86/3500 train loss: [array(0.10326145, dtype=float32)], val loss: 0.09973370283842087
# 	 partial train loss (single batch): 0.101448
# Epoch 87/3500 train loss: [array(0.10144753, dtype=float32)], val loss: 0.09990641474723816
# 	 partial train loss (single batch): 0.102457
# Epoch 88/3500 train loss: [array(0.10245691, dtype=float32)], val loss: 0.09741158038377762
# 	 partial train loss (single batch): 0.101491
# Epoch 89/3500 train loss: [array(0.10149124, dtype=float32)], val loss: 0.09965331852436066
# 	 partial train loss (single batch): 0.100030
# Epoch 90/3500 train loss: [array(0.10003003, dtype=float32)], val loss: 0.09990796446800232
# 	 partial train loss (single batch): 0.098641
# Epoch 91/3500 train loss: [array(0.0986411, dtype=float32)], val loss: 0.09907115250825882
# 	 partial train loss (single batch): 0.099663
# Epoch 92/3500 train loss: [array(0.09966311, dtype=float32)], val loss: 0.09726464003324509
# 	 partial train loss (single batch): 0.097925
# Epoch 93/3500 train loss: [array(0.09792515, dtype=float32)], val loss: 0.09767381846904755
# 	 partial train loss (single batch): 0.099213
# Epoch 94/3500 train loss: [array(0.09921268, dtype=float32)], val loss: 0.09562476724386215
# 	 partial train loss (single batch): 0.097295
# Epoch 95/3500 train loss: [array(0.09729473, dtype=float32)], val loss: 0.09618254750967026
# 	 partial train loss (single batch): 0.095635
# Epoch 96/3500 train loss: [array(0.09563491, dtype=float32)], val loss: 0.09724857658147812
# 	 partial train loss (single batch): 0.096022
# Epoch 97/3500 train loss: [array(0.09602199, dtype=float32)], val loss: 0.09451264888048172
# 	 partial train loss (single batch): 0.095211
# Epoch 98/3500 train loss: [array(0.09521078, dtype=float32)], val loss: 0.09356294572353363
# 	 partial train loss (single batch): 0.095508
# Epoch 99/3500 train loss: [array(0.09550847, dtype=float32)], val loss: 0.09245048463344574
# 	 partial train loss (single batch): 0.095226
# Epoch 100/3500 train loss: [array(0.09522551, dtype=float32)], val loss: 0.09311390668153763
# 	 partial train loss (single batch): 0.095739
# Epoch 101/3500 train loss: [array(0.09573875, dtype=float32)], val loss: 0.09586693346500397
# 	 partial train loss (single batch): 0.095453
# Epoch 102/3500 train loss: [array(0.09545317, dtype=float32)], val loss: 0.0929226204752922
# 	 partial train loss (single batch): 0.092716
# Epoch 103/3500 train loss: [array(0.0927164, dtype=float32)], val loss: 0.09202919155359268
# 	 partial train loss (single batch): 0.092850
# Epoch 104/3500 train loss: [array(0.09284953, dtype=float32)], val loss: 0.09025312960147858
# 	 partial train loss (single batch): 0.090820
# Epoch 105/3500 train loss: [array(0.0908201, dtype=float32)], val loss: 0.08958170562982559
# 	 partial train loss (single batch): 0.091189
# Epoch 106/3500 train loss: [array(0.09118869, dtype=float32)], val loss: 0.09055183082818985
# 	 partial train loss (single batch): 0.091420
# Epoch 107/3500 train loss: [array(0.09141973, dtype=float32)], val loss: 0.09032262861728668
# 	 partial train loss (single batch): 0.090826
# Epoch 108/3500 train loss: [array(0.09082638, dtype=float32)], val loss: 0.08976168185472488
# 	 partial train loss (single batch): 0.090071
# Epoch 109/3500 train loss: [array(0.09007146, dtype=float32)], val loss: 0.08823931217193604
# 	 partial train loss (single batch): 0.088419
# Epoch 110/3500 train loss: [array(0.08841892, dtype=float32)], val loss: 0.08841187506914139
# 	 partial train loss (single batch): 0.089494
# Epoch 111/3500 train loss: [array(0.08949406, dtype=float32)], val loss: 0.0889681801199913
# 	 partial train loss (single batch): 0.089967
# Epoch 112/3500 train loss: [array(0.08996665, dtype=float32)], val loss: 0.08893118798732758
# 	 partial train loss (single batch): 0.088966
# Epoch 113/3500 train loss: [array(0.08896573, dtype=float32)], val loss: 0.08701096475124359
# 	 partial train loss (single batch): 0.088644
# Epoch 114/3500 train loss: [array(0.08864437, dtype=float32)], val loss: 0.08758309483528137
# 	 partial train loss (single batch): 0.087480
# Epoch 115/3500 train loss: [array(0.08748022, dtype=float32)], val loss: 0.085311159491539
# 	 partial train loss (single batch): 0.087560
# Epoch 116/3500 train loss: [array(0.08756007, dtype=float32)], val loss: 0.08829336613416672
# 	 partial train loss (single batch): 0.086733
# Epoch 117/3500 train loss: [array(0.0867328, dtype=float32)], val loss: 0.08500702679157257
# 	 partial train loss (single batch): 0.087854
# Epoch 118/3500 train loss: [array(0.08785436, dtype=float32)], val loss: 0.08579988777637482
# 	 partial train loss (single batch): 0.085846
# Epoch 119/3500 train loss: [array(0.08584559, dtype=float32)], val loss: 0.08499466627836227
# 	 partial train loss (single batch): 0.087241
# Epoch 120/3500 train loss: [array(0.08724115, dtype=float32)], val loss: 0.08580326288938522
# 	 partial train loss (single batch): 0.086227
# Epoch 121/3500 train loss: [array(0.08622734, dtype=float32)], val loss: 0.08604148775339127
# 	 partial train loss (single batch): 0.086127
# Epoch 122/3500 train loss: [array(0.08612743, dtype=float32)], val loss: 0.08460959792137146
# 	 partial train loss (single batch): 0.086108
# Epoch 123/3500 train loss: [array(0.08610753, dtype=float32)], val loss: 0.08217573910951614
# 	 partial train loss (single batch): 0.085271
# Epoch 124/3500 train loss: [array(0.08527125, dtype=float32)], val loss: 0.08587309718132019
# 	 partial train loss (single batch): 0.084780
# Epoch 125/3500 train loss: [array(0.08478013, dtype=float32)], val loss: 0.08408822864294052
# 	 partial train loss (single batch): 0.086321
# Epoch 126/3500 train loss: [array(0.08632125, dtype=float32)], val loss: 0.08293571323156357
# 	 partial train loss (single batch): 0.082368
# Epoch 127/3500 train loss: [array(0.08236775, dtype=float32)], val loss: 0.08369207382202148
# 	 partial train loss (single batch): 0.084012
# Epoch 128/3500 train loss: [array(0.08401196, dtype=float32)], val loss: 0.08095788955688477
# 	 partial train loss (single batch): 0.084068
# Epoch 129/3500 train loss: [array(0.08406835, dtype=float32)], val loss: 0.08316268771886826
# 	 partial train loss (single batch): 0.083223
# Epoch 130/3500 train loss: [array(0.08322296, dtype=float32)], val loss: 0.07998908311128616
# 	 partial train loss (single batch): 0.083468
# Epoch 131/3500 train loss: [array(0.08346821, dtype=float32)], val loss: 0.08336235582828522
# 	 partial train loss (single batch): 0.082630
# Epoch 132/3500 train loss: [array(0.08262976, dtype=float32)], val loss: 0.07987502217292786
# 	 partial train loss (single batch): 0.081885
# Epoch 133/3500 train loss: [array(0.08188514, dtype=float32)], val loss: 0.08120768517255783
# 	 partial train loss (single batch): 0.081181
# Epoch 134/3500 train loss: [array(0.08118103, dtype=float32)], val loss: 0.07853423058986664
# 	 partial train loss (single batch): 0.082057
# Epoch 135/3500 train loss: [array(0.08205669, dtype=float32)], val loss: 0.08213764429092407
# 	 partial train loss (single batch): 0.082065
# Epoch 136/3500 train loss: [array(0.08206472, dtype=float32)], val loss: 0.0817209780216217
# 	 partial train loss (single batch): 0.080393
# Epoch 137/3500 train loss: [array(0.08039331, dtype=float32)], val loss: 0.08109311014413834
# 	 partial train loss (single batch): 0.080385
# Epoch 138/3500 train loss: [array(0.08038452, dtype=float32)], val loss: 0.0786726325750351
# 	 partial train loss (single batch): 0.080428
# Epoch 139/3500 train loss: [array(0.08042832, dtype=float32)], val loss: 0.08179356902837753
# 	 partial train loss (single batch): 0.079760
# Epoch 140/3500 train loss: [array(0.0797603, dtype=float32)], val loss: 0.07945461571216583
# 	 partial train loss (single batch): 0.079850
# Epoch 141/3500 train loss: [array(0.07984997, dtype=float32)], val loss: 0.08046156167984009
# 	 partial train loss (single batch): 0.079733
# Epoch 142/3500 train loss: [array(0.07973308, dtype=float32)], val loss: 0.08040212839841843
# 	 partial train loss (single batch): 0.080216
# Epoch 143/3500 train loss: [array(0.08021563, dtype=float32)], val loss: 0.07876911014318466
# 	 partial train loss (single batch): 0.078756
# Epoch 144/3500 train loss: [array(0.07875565, dtype=float32)], val loss: 0.07822336256504059
# 	 partial train loss (single batch): 0.077542
# Epoch 145/3500 train loss: [array(0.07754221, dtype=float32)], val loss: 0.07926963269710541
# 	 partial train loss (single batch): 0.078142
# Epoch 146/3500 train loss: [array(0.0781421, dtype=float32)], val loss: 0.07678081840276718
# 	 partial train loss (single batch): 0.078870
# Epoch 147/3500 train loss: [array(0.07886982, dtype=float32)], val loss: 0.07816412299871445
# 	 partial train loss (single batch): 0.076517
# Epoch 148/3500 train loss: [array(0.07651744, dtype=float32)], val loss: 0.07777858525514603
# 	 partial train loss (single batch): 0.078044
# Epoch 149/3500 train loss: [array(0.07804434, dtype=float32)], val loss: 0.07744257152080536
# 	 partial train loss (single batch): 0.076824
# Epoch 150/3500 train loss: [array(0.07682407, dtype=float32)], val loss: 0.07900578528642654
# 	 partial train loss (single batch): 0.077418
# Epoch 151/3500 train loss: [array(0.07741818, dtype=float32)], val loss: 0.07669837027788162
# 	 partial train loss (single batch): 0.079572
# Epoch 152/3500 train loss: [array(0.07957159, dtype=float32)], val loss: 0.07688327878713608
# 	 partial train loss (single batch): 0.078074
# Epoch 153/3500 train loss: [array(0.07807416, dtype=float32)], val loss: 0.07758989930152893
# 	 partial train loss (single batch): 0.076171
# Epoch 154/3500 train loss: [array(0.07617106, dtype=float32)], val loss: 0.07623722404241562
# 	 partial train loss (single batch): 0.076676
# Epoch 155/3500 train loss: [array(0.07667585, dtype=float32)], val loss: 0.07820891588926315
# 	 partial train loss (single batch): 0.077090
# Epoch 156/3500 train loss: [array(0.07708994, dtype=float32)], val loss: 0.07716575264930725
# 	 partial train loss (single batch): 0.075897
# Epoch 157/3500 train loss: [array(0.07589727, dtype=float32)], val loss: 0.0792243629693985
# 	 partial train loss (single batch): 0.077596
# Epoch 158/3500 train loss: [array(0.07759649, dtype=float32)], val loss: 0.07483568042516708
# 	 partial train loss (single batch): 0.077036
# Epoch 159/3500 train loss: [array(0.07703623, dtype=float32)], val loss: 0.0761926919221878
# 	 partial train loss (single batch): 0.076354
# Epoch 160/3500 train loss: [array(0.076354, dtype=float32)], val loss: 0.07491028308868408
# 	 partial train loss (single batch): 0.076434
# Epoch 161/3500 train loss: [array(0.07643421, dtype=float32)], val loss: 0.07818435877561569
# 	 partial train loss (single batch): 0.075630
# Epoch 162/3500 train loss: [array(0.07563021, dtype=float32)], val loss: 0.07484330236911774
# 	 partial train loss (single batch): 0.075776
# Epoch 163/3500 train loss: [array(0.07577559, dtype=float32)], val loss: 0.07376698404550552
# 	 partial train loss (single batch): 0.075275
# Epoch 164/3500 train loss: [array(0.07527504, dtype=float32)], val loss: 0.07628548890352249
# 	 partial train loss (single batch): 0.075027
# Epoch 165/3500 train loss: [array(0.07502697, dtype=float32)], val loss: 0.07572916895151138
# 	 partial train loss (single batch): 0.075842
# Epoch 166/3500 train loss: [array(0.07584242, dtype=float32)], val loss: 0.0748242735862732
# 	 partial train loss (single batch): 0.074840
# Epoch 167/3500 train loss: [array(0.07483964, dtype=float32)], val loss: 0.0757618248462677
# 	 partial train loss (single batch): 0.076286
# Epoch 168/3500 train loss: [array(0.07628586, dtype=float32)], val loss: 0.07651742547750473
# 	 partial train loss (single batch): 0.074856
# Epoch 169/3500 train loss: [array(0.07485583, dtype=float32)], val loss: 0.07419262826442719
# 	 partial train loss (single batch): 0.073891
# Epoch 170/3500 train loss: [array(0.07389119, dtype=float32)], val loss: 0.07598485797643661
# 	 partial train loss (single batch): 0.074750
# Epoch 171/3500 train loss: [array(0.07474976, dtype=float32)], val loss: 0.07520505040884018
# 	 partial train loss (single batch): 0.073691
# Epoch 172/3500 train loss: [array(0.07369052, dtype=float32)], val loss: 0.07520581036806107
# 	 partial train loss (single batch): 0.075193
# Epoch 173/3500 train loss: [array(0.07519319, dtype=float32)], val loss: 0.07458995282649994
# 	 partial train loss (single batch): 0.072332
# Epoch 174/3500 train loss: [array(0.07233199, dtype=float32)], val loss: 0.07400678098201752
# 	 partial train loss (single batch): 0.072452
# Epoch 175/3500 train loss: [array(0.07245154, dtype=float32)], val loss: 0.07483354210853577
# 	 partial train loss (single batch): 0.072693
# Epoch 176/3500 train loss: [array(0.07269264, dtype=float32)], val loss: 0.07290248572826385
# 	 partial train loss (single batch): 0.072692
# Epoch 177/3500 train loss: [array(0.0726919, dtype=float32)], val loss: 0.07428675889968872
# 	 partial train loss (single batch): 0.074876
# Epoch 178/3500 train loss: [array(0.07487608, dtype=float32)], val loss: 0.07342028617858887
# 	 partial train loss (single batch): 0.073769
# Epoch 179/3500 train loss: [array(0.07376947, dtype=float32)], val loss: 0.07348974049091339
# 	 partial train loss (single batch): 0.072618
# Epoch 180/3500 train loss: [array(0.07261808, dtype=float32)], val loss: 0.07372373342514038
# 	 partial train loss (single batch): 0.072221
# Epoch 181/3500 train loss: [array(0.07222059, dtype=float32)], val loss: 0.07421252131462097
# 	 partial train loss (single batch): 0.071530
# Epoch 182/3500 train loss: [array(0.07152972, dtype=float32)], val loss: 0.07194526493549347
# 	 partial train loss (single batch): 0.073126
# Epoch 183/3500 train loss: [array(0.0731259, dtype=float32)], val loss: 0.07211216539144516
# 	 partial train loss (single batch): 0.072310
# Epoch 184/3500 train loss: [array(0.07230981, dtype=float32)], val loss: 0.07218406349420547
# 	 partial train loss (single batch): 0.074423
# Epoch 185/3500 train loss: [array(0.07442259, dtype=float32)], val loss: 0.07297984510660172
# 	 partial train loss (single batch): 0.071096
# Epoch 186/3500 train loss: [array(0.07109552, dtype=float32)], val loss: 0.0721316859126091
# 	 partial train loss (single batch): 0.071676
# Epoch 187/3500 train loss: [array(0.07167635, dtype=float32)], val loss: 0.07283278554677963
# 	 partial train loss (single batch): 0.070177
# Epoch 188/3500 train loss: [array(0.07017745, dtype=float32)], val loss: 0.07310227304697037
# 	 partial train loss (single batch): 0.069547
# Epoch 189/3500 train loss: [array(0.06954718, dtype=float32)], val loss: 0.0707956999540329
# 	 partial train loss (single batch): 0.070770
# Epoch 190/3500 train loss: [array(0.07077037, dtype=float32)], val loss: 0.07147589325904846
# 	 partial train loss (single batch): 0.070694
# Epoch 191/3500 train loss: [array(0.0706943, dtype=float32)], val loss: 0.07033615559339523
# 	 partial train loss (single batch): 0.070322
# Epoch 192/3500 train loss: [array(0.0703215, dtype=float32)], val loss: 0.07052945345640182
# 	 partial train loss (single batch): 0.071742
# Epoch 193/3500 train loss: [array(0.07174178, dtype=float32)], val loss: 0.06998353451490402
# 	 partial train loss (single batch): 0.072216
# Epoch 194/3500 train loss: [array(0.07221591, dtype=float32)], val loss: 0.07170934230089188
# 	 partial train loss (single batch): 0.070566
# Epoch 195/3500 train loss: [array(0.07056645, dtype=float32)], val loss: 0.07186699658632278
# 	 partial train loss (single batch): 0.070537
# Epoch 196/3500 train loss: [array(0.07053689, dtype=float32)], val loss: 0.07059753686189651
# 	 partial train loss (single batch): 0.070169
# Epoch 197/3500 train loss: [array(0.07016885, dtype=float32)], val loss: 0.06936690956354141
# 	 partial train loss (single batch): 0.070310
# Epoch 198/3500 train loss: [array(0.0703099, dtype=float32)], val loss: 0.0709928423166275
# 	 partial train loss (single batch): 0.071003
# Epoch 199/3500 train loss: [array(0.07100282, dtype=float32)], val loss: 0.0718674436211586
# 	 partial train loss (single batch): 0.070641
# Epoch 200/3500 train loss: [array(0.07064094, dtype=float32)], val loss: 0.07227044552564621
# 	 partial train loss (single batch): 0.069624
# Epoch 201/3500 train loss: [array(0.06962413, dtype=float32)], val loss: 0.07244521379470825
# 	 partial train loss (single batch): 0.070105
# Epoch 202/3500 train loss: [array(0.07010491, dtype=float32)], val loss: 0.0689709261059761
# 	 partial train loss (single batch): 0.070978
# Epoch 203/3500 train loss: [array(0.07097778, dtype=float32)], val loss: 0.07071251422166824
# 	 partial train loss (single batch): 0.069098
# Epoch 204/3500 train loss: [array(0.06909841, dtype=float32)], val loss: 0.07084944099187851
# 	 partial train loss (single batch): 0.072237
# Epoch 205/3500 train loss: [array(0.07223704, dtype=float32)], val loss: 0.07113559544086456
# 	 partial train loss (single batch): 0.068782
# Epoch 206/3500 train loss: [array(0.0687824, dtype=float32)], val loss: 0.06983289122581482
# 	 partial train loss (single batch): 0.069926
# Epoch 207/3500 train loss: [array(0.06992572, dtype=float32)], val loss: 0.07063858211040497
# 	 partial train loss (single batch): 0.070531
# Epoch 208/3500 train loss: [array(0.07053109, dtype=float32)], val loss: 0.06966890394687653
# 	 partial train loss (single batch): 0.068448
# Epoch 209/3500 train loss: [array(0.06844757, dtype=float32)], val loss: 0.07040072232484818
# 	 partial train loss (single batch): 0.069633
# Epoch 210/3500 train loss: [array(0.06963288, dtype=float32)], val loss: 0.07117561250925064
# 	 partial train loss (single batch): 0.068820
# Epoch 211/3500 train loss: [array(0.06882033, dtype=float32)], val loss: 0.06973323225975037
# 	 partial train loss (single batch): 0.068491
# Epoch 212/3500 train loss: [array(0.06849083, dtype=float32)], val loss: 0.06793021410703659
# 	 partial train loss (single batch): 0.069044
# Epoch 213/3500 train loss: [array(0.06904373, dtype=float32)], val loss: 0.06975986808538437
# 	 partial train loss (single batch): 0.068530
# Epoch 214/3500 train loss: [array(0.06853028, dtype=float32)], val loss: 0.07055294513702393
# 	 partial train loss (single batch): 0.069206
# Epoch 215/3500 train loss: [array(0.0692061, dtype=float32)], val loss: 0.07005103677511215
# 	 partial train loss (single batch): 0.067543
# Epoch 216/3500 train loss: [array(0.06754255, dtype=float32)], val loss: 0.06865092366933823
# 	 partial train loss (single batch): 0.067652
# Epoch 217/3500 train loss: [array(0.06765239, dtype=float32)], val loss: 0.06837207823991776
# 	 partial train loss (single batch): 0.068841
# Epoch 218/3500 train loss: [array(0.06884134, dtype=float32)], val loss: 0.06969086825847626
# 	 partial train loss (single batch): 0.068440
# Epoch 219/3500 train loss: [array(0.06843955, dtype=float32)], val loss: 0.06961077451705933
# 	 partial train loss (single batch): 0.070537
# Epoch 220/3500 train loss: [array(0.07053671, dtype=float32)], val loss: 0.06888476014137268
# 	 partial train loss (single batch): 0.068494
# Epoch 221/3500 train loss: [array(0.06849379, dtype=float32)], val loss: 0.06910572201013565
# 	 partial train loss (single batch): 0.067512
# Epoch 222/3500 train loss: [array(0.06751244, dtype=float32)], val loss: 0.06890768557786942
# 	 partial train loss (single batch): 0.068488
# Epoch 223/3500 train loss: [array(0.06848806, dtype=float32)], val loss: 0.06509405374526978
# 	 partial train loss (single batch): 0.068018
# Epoch 224/3500 train loss: [array(0.0680185, dtype=float32)], val loss: 0.06943877786397934
# 	 partial train loss (single batch): 0.066818
# Epoch 225/3500 train loss: [array(0.06681788, dtype=float32)], val loss: 0.06921041011810303
# 	 partial train loss (single batch): 0.068181
# Epoch 226/3500 train loss: [array(0.06818064, dtype=float32)], val loss: 0.06876210868358612
# 	 partial train loss (single batch): 0.068014
# Epoch 227/3500 train loss: [array(0.06801411, dtype=float32)], val loss: 0.06752466410398483
# 	 partial train loss (single batch): 0.068761
# Epoch 228/3500 train loss: [array(0.06876065, dtype=float32)], val loss: 0.06720694899559021
# 	 partial train loss (single batch): 0.067090
# Epoch 229/3500 train loss: [array(0.06708962, dtype=float32)], val loss: 0.0666300356388092
# 	 partial train loss (single batch): 0.067046
# Epoch 230/3500 train loss: [array(0.06704587, dtype=float32)], val loss: 0.06806806474924088
# 	 partial train loss (single batch): 0.067930
# Epoch 231/3500 train loss: [array(0.06793046, dtype=float32)], val loss: 0.0680025964975357
# 	 partial train loss (single batch): 0.067071
# Epoch 232/3500 train loss: [array(0.06707115, dtype=float32)], val loss: 0.06389077007770538
# 	 partial train loss (single batch): 0.066671
# Epoch 233/3500 train loss: [array(0.06667062, dtype=float32)], val loss: 0.0680830255150795
# 	 partial train loss (single batch): 0.068844
# Epoch 234/3500 train loss: [array(0.06884409, dtype=float32)], val loss: 0.06806135922670364
# 	 partial train loss (single batch): 0.066348
# Epoch 235/3500 train loss: [array(0.06634768, dtype=float32)], val loss: 0.06817257404327393
# 	 partial train loss (single batch): 0.066406
# Epoch 236/3500 train loss: [array(0.06640602, dtype=float32)], val loss: 0.06775089353322983
# 	 partial train loss (single batch): 0.067041
# Epoch 237/3500 train loss: [array(0.06704128, dtype=float32)], val loss: 0.06791301816701889
# 	 partial train loss (single batch): 0.067712
# Epoch 238/3500 train loss: [array(0.06771188, dtype=float32)], val loss: 0.06591303646564484
# 	 partial train loss (single batch): 0.066842
# Epoch 239/3500 train loss: [array(0.06684199, dtype=float32)], val loss: 0.06613688915967941
# 	 partial train loss (single batch): 0.065989
# Epoch 240/3500 train loss: [array(0.06598886, dtype=float32)], val loss: 0.06673315912485123
# 	 partial train loss (single batch): 0.064679
# Epoch 241/3500 train loss: [array(0.06467905, dtype=float32)], val loss: 0.06759407371282578
# 	 partial train loss (single batch): 0.065993
# Epoch 242/3500 train loss: [array(0.06599335, dtype=float32)], val loss: 0.0664612203836441
# 	 partial train loss (single batch): 0.066317
# Epoch 243/3500 train loss: [array(0.06631747, dtype=float32)], val loss: 0.06656774133443832
# 	 partial train loss (single batch): 0.066372
# Epoch 244/3500 train loss: [array(0.06637154, dtype=float32)], val loss: 0.06491736322641373
# 	 partial train loss (single batch): 0.065177
# Epoch 245/3500 train loss: [array(0.06517697, dtype=float32)], val loss: 0.06625595688819885
# 	 partial train loss (single batch): 0.063937
# Epoch 246/3500 train loss: [array(0.06393709, dtype=float32)], val loss: 0.06525563448667526
# 	 partial train loss (single batch): 0.065446
# Epoch 247/3500 train loss: [array(0.06544609, dtype=float32)], val loss: 0.06654983758926392
# 	 partial train loss (single batch): 0.066112
# Epoch 248/3500 train loss: [array(0.06611167, dtype=float32)], val loss: 0.06514347344636917
# 	 partial train loss (single batch): 0.067752
# Epoch 249/3500 train loss: [array(0.06775247, dtype=float32)], val loss: 0.06434368342161179
# 	 partial train loss (single batch): 0.064500
# Epoch 250/3500 train loss: [array(0.06449971, dtype=float32)], val loss: 0.0651172399520874
# 	 partial train loss (single batch): 0.065529
# Epoch 251/3500 train loss: [array(0.06552882, dtype=float32)], val loss: 0.06518933176994324
# 	 partial train loss (single batch): 0.062513
# Epoch 252/3500 train loss: [array(0.06251332, dtype=float32)], val loss: 0.0629301369190216
# 	 partial train loss (single batch): 0.064744
# Epoch 253/3500 train loss: [array(0.06474406, dtype=float32)], val loss: 0.06411080062389374
# 	 partial train loss (single batch): 0.066491
# Epoch 254/3500 train loss: [array(0.06649067, dtype=float32)], val loss: 0.06462226808071136
# 	 partial train loss (single batch): 0.062694
# Epoch 255/3500 train loss: [array(0.06269381, dtype=float32)], val loss: 0.06488199532032013
# 	 partial train loss (single batch): 0.065053
# Epoch 256/3500 train loss: [array(0.06505309, dtype=float32)], val loss: 0.06487584859132767
# 	 partial train loss (single batch): 0.062709
# Epoch 257/3500 train loss: [array(0.0627085, dtype=float32)], val loss: 0.06386037915945053
# 	 partial train loss (single batch): 0.064400
# Epoch 258/3500 train loss: [array(0.06440017, dtype=float32)], val loss: 0.06274618208408356
# 	 partial train loss (single batch): 0.064308
# Epoch 259/3500 train loss: [array(0.0643084, dtype=float32)], val loss: 0.06185055896639824
# 	 partial train loss (single batch): 0.063321
# Epoch 260/3500 train loss: [array(0.06332107, dtype=float32)], val loss: 0.06424588710069656
# 	 partial train loss (single batch): 0.062768
# Epoch 261/3500 train loss: [array(0.06276774, dtype=float32)], val loss: 0.06278436630964279
# 	 partial train loss (single batch): 0.063040
# Epoch 262/3500 train loss: [array(0.06303988, dtype=float32)], val loss: 0.06466271728277206
# 	 partial train loss (single batch): 0.063117
# Epoch 263/3500 train loss: [array(0.06311651, dtype=float32)], val loss: 0.06274106353521347
# 	 partial train loss (single batch): 0.062830
# Epoch 264/3500 train loss: [array(0.06283017, dtype=float32)], val loss: 0.06251148134469986
# 	 partial train loss (single batch): 0.063612
# Epoch 265/3500 train loss: [array(0.06361226, dtype=float32)], val loss: 0.06221642717719078
# 	 partial train loss (single batch): 0.062806
# Epoch 266/3500 train loss: [array(0.06280588, dtype=float32)], val loss: 0.0615670345723629
# 	 partial train loss (single batch): 0.062736
# Epoch 267/3500 train loss: [array(0.062736, dtype=float32)], val loss: 0.06365577131509781
# 	 partial train loss (single batch): 0.063338
# Epoch 268/3500 train loss: [array(0.06333825, dtype=float32)], val loss: 0.06272193044424057
# 	 partial train loss (single batch): 0.062961
# Epoch 269/3500 train loss: [array(0.06296129, dtype=float32)], val loss: 0.0635533407330513
# 	 partial train loss (single batch): 0.063683
# Epoch 270/3500 train loss: [array(0.06368304, dtype=float32)], val loss: 0.06296046823263168
# 	 partial train loss (single batch): 0.061307
# Epoch 271/3500 train loss: [array(0.06130692, dtype=float32)], val loss: 0.06217207759618759
# 	 partial train loss (single batch): 0.062182
# Epoch 272/3500 train loss: [array(0.06218231, dtype=float32)], val loss: 0.060892023146152496
# 	 partial train loss (single batch): 0.061487
# Epoch 273/3500 train loss: [array(0.0614875, dtype=float32)], val loss: 0.06240960583090782
# 	 partial train loss (single batch): 0.062592
# Epoch 274/3500 train loss: [array(0.06259199, dtype=float32)], val loss: 0.0609295517206192
# 	 partial train loss (single batch): 0.061928
# Epoch 275/3500 train loss: [array(0.06192805, dtype=float32)], val loss: 0.06275320798158646
# 	 partial train loss (single batch): 0.062933
# Epoch 276/3500 train loss: [array(0.06293284, dtype=float32)], val loss: 0.059375908225774765
# 	 partial train loss (single batch): 0.061012
# Epoch 277/3500 train loss: [array(0.06101189, dtype=float32)], val loss: 0.05975732207298279
# 	 partial train loss (single batch): 0.059291
# Epoch 278/3500 train loss: [array(0.05929101, dtype=float32)], val loss: 0.060639068484306335
# 	 partial train loss (single batch): 0.058535
# Epoch 279/3500 train loss: [array(0.05853453, dtype=float32)], val loss: 0.06118936836719513
# 	 partial train loss (single batch): 0.060126
# Epoch 280/3500 train loss: [array(0.06012631, dtype=float32)], val loss: 0.06046411767601967
# 	 partial train loss (single batch): 0.059708
# Epoch 281/3500 train loss: [array(0.05970762, dtype=float32)], val loss: 0.06218941509723663
# 	 partial train loss (single batch): 0.060448
# Epoch 282/3500 train loss: [array(0.06044817, dtype=float32)], val loss: 0.05920788645744324
# 	 partial train loss (single batch): 0.060677
# Epoch 283/3500 train loss: [array(0.06067737, dtype=float32)], val loss: 0.060246989130973816
# 	 partial train loss (single batch): 0.059918
# Epoch 284/3500 train loss: [array(0.05991785, dtype=float32)], val loss: 0.0614708848297596
# 	 partial train loss (single batch): 0.058859
# Epoch 285/3500 train loss: [array(0.05885928, dtype=float32)], val loss: 0.05871318280696869
# 	 partial train loss (single batch): 0.061219
# Epoch 286/3500 train loss: [array(0.06121918, dtype=float32)], val loss: 0.06012946367263794
# 	 partial train loss (single batch): 0.059052
# Epoch 287/3500 train loss: [array(0.05905156, dtype=float32)], val loss: 0.05948176607489586
# 	 partial train loss (single batch): 0.058608
# Epoch 288/3500 train loss: [array(0.05860807, dtype=float32)], val loss: 0.06020893529057503
# 	 partial train loss (single batch): 0.060003
# Epoch 289/3500 train loss: [array(0.06000261, dtype=float32)], val loss: 0.058003462851047516
# 	 partial train loss (single batch): 0.060811
# Epoch 290/3500 train loss: [array(0.06081108, dtype=float32)], val loss: 0.05771448090672493
# 	 partial train loss (single batch): 0.059424
# Epoch 291/3500 train loss: [array(0.059424, dtype=float32)], val loss: 0.056910499930381775
# 	 partial train loss (single batch): 0.058128
# Epoch 292/3500 train loss: [array(0.0581279, dtype=float32)], val loss: 0.05949638411402702
# 	 partial train loss (single batch): 0.056868
# Epoch 293/3500 train loss: [array(0.05686846, dtype=float32)], val loss: 0.05951285362243652
# 	 partial train loss (single batch): 0.057063
# Epoch 294/3500 train loss: [array(0.05706317, dtype=float32)], val loss: 0.05767004191875458
# 	 partial train loss (single batch): 0.056965
# Epoch 295/3500 train loss: [array(0.05696527, dtype=float32)], val loss: 0.05723106488585472
# 	 partial train loss (single batch): 0.058898
# Epoch 296/3500 train loss: [array(0.05889777, dtype=float32)], val loss: 0.058543890714645386
# 	 partial train loss (single batch): 0.058009
# Epoch 297/3500 train loss: [array(0.05800946, dtype=float32)], val loss: 0.05761168897151947
# 	 partial train loss (single batch): 0.056905
# Epoch 298/3500 train loss: [array(0.0569054, dtype=float32)], val loss: 0.05754583328962326
# 	 partial train loss (single batch): 0.058885
# Epoch 299/3500 train loss: [array(0.05888519, dtype=float32)], val loss: 0.05850573629140854
# 	 partial train loss (single batch): 0.058619
# Epoch 300/3500 train loss: [array(0.05861885, dtype=float32)], val loss: 0.06013639643788338
# 	 partial train loss (single batch): 0.058502
# Epoch 301/3500 train loss: [array(0.05850158, dtype=float32)], val loss: 0.057843975722789764
# 	 partial train loss (single batch): 0.058173
# Epoch 302/3500 train loss: [array(0.05817316, dtype=float32)], val loss: 0.05695442110300064
# 	 partial train loss (single batch): 0.056054
# Epoch 303/3500 train loss: [array(0.05605435, dtype=float32)], val loss: 0.056302689015865326
# 	 partial train loss (single batch): 0.056452
# Epoch 304/3500 train loss: [array(0.05645224, dtype=float32)], val loss: 0.057356324046850204
# 	 partial train loss (single batch): 0.057162
# Epoch 305/3500 train loss: [array(0.0571623, dtype=float32)], val loss: 0.05648001283407211
# 	 partial train loss (single batch): 0.058077
# Epoch 306/3500 train loss: [array(0.05807717, dtype=float32)], val loss: 0.057098787277936935
# 	 partial train loss (single batch): 0.057120
# Epoch 307/3500 train loss: [array(0.05711976, dtype=float32)], val loss: 0.057188794016838074
# 	 partial train loss (single batch): 0.055912
# Epoch 308/3500 train loss: [array(0.05591186, dtype=float32)], val loss: 0.056568242609500885
# 	 partial train loss (single batch): 0.055403
# Epoch 309/3500 train loss: [array(0.05540347, dtype=float32)], val loss: 0.05596359819173813
# 	 partial train loss (single batch): 0.057411
# Epoch 310/3500 train loss: [array(0.05741102, dtype=float32)], val loss: 0.056489307433366776
# 	 partial train loss (single batch): 0.056726
# Epoch 311/3500 train loss: [array(0.05672574, dtype=float32)], val loss: 0.054771676659584045
# 	 partial train loss (single batch): 0.057131
# Epoch 312/3500 train loss: [array(0.05713119, dtype=float32)], val loss: 0.05518878623843193
# 	 partial train loss (single batch): 0.056200
# Epoch 313/3500 train loss: [array(0.05619987, dtype=float32)], val loss: 0.05495087802410126
# 	 partial train loss (single batch): 0.054494
# Epoch 314/3500 train loss: [array(0.05449434, dtype=float32)], val loss: 0.05472752824425697
# 	 partial train loss (single batch): 0.058008
# Epoch 315/3500 train loss: [array(0.05800771, dtype=float32)], val loss: 0.05512889474630356
# 	 partial train loss (single batch): 0.055729
# Epoch 316/3500 train loss: [array(0.05572914, dtype=float32)], val loss: 0.05529145896434784
# 	 partial train loss (single batch): 0.057602
# Epoch 317/3500 train loss: [array(0.05760157, dtype=float32)], val loss: 0.0552440844476223
# 	 partial train loss (single batch): 0.054985
# Epoch 318/3500 train loss: [array(0.05498456, dtype=float32)], val loss: 0.056380584836006165
# 	 partial train loss (single batch): 0.053998
# Epoch 319/3500 train loss: [array(0.05399755, dtype=float32)], val loss: 0.055345650762319565
# 	 partial train loss (single batch): 0.055951
# Epoch 320/3500 train loss: [array(0.05595145, dtype=float32)], val loss: 0.05586698651313782
# 	 partial train loss (single batch): 0.057166
# Epoch 321/3500 train loss: [array(0.05716592, dtype=float32)], val loss: 0.05427331477403641
# 	 partial train loss (single batch): 0.053877
# Epoch 322/3500 train loss: [array(0.05387737, dtype=float32)], val loss: 0.055866241455078125
# 	 partial train loss (single batch): 0.055896
# Epoch 323/3500 train loss: [array(0.05589602, dtype=float32)], val loss: 0.05228668823838234
# 	 partial train loss (single batch): 0.054313
# Epoch 324/3500 train loss: [array(0.05431317, dtype=float32)], val loss: 0.05613959580659866
# 	 partial train loss (single batch): 0.054510
# Epoch 325/3500 train loss: [array(0.05450967, dtype=float32)], val loss: 0.05388788878917694
# 	 partial train loss (single batch): 0.053339
# Epoch 326/3500 train loss: [array(0.05333856, dtype=float32)], val loss: 0.05286896973848343
# 	 partial train loss (single batch): 0.052865
# Epoch 327/3500 train loss: [array(0.05286539, dtype=float32)], val loss: 0.05514674261212349
# 	 partial train loss (single batch): 0.055161
# Epoch 328/3500 train loss: [array(0.05516111, dtype=float32)], val loss: 0.052430834621191025
# 	 partial train loss (single batch): 0.053687
# Epoch 329/3500 train loss: [array(0.05368748, dtype=float32)], val loss: 0.053173426538705826
# 	 partial train loss (single batch): 0.053718
# Epoch 330/3500 train loss: [array(0.05371798, dtype=float32)], val loss: 0.05305051431059837
# 	 partial train loss (single batch): 0.053268
# Epoch 331/3500 train loss: [array(0.05326815, dtype=float32)], val loss: 0.0522640198469162
# 	 partial train loss (single batch): 0.053824
# Epoch 332/3500 train loss: [array(0.05382405, dtype=float32)], val loss: 0.053795453161001205
# 	 partial train loss (single batch): 0.054211
# Epoch 333/3500 train loss: [array(0.05421138, dtype=float32)], val loss: 0.05296000838279724
# 	 partial train loss (single batch): 0.054181
# Epoch 334/3500 train loss: [array(0.05418099, dtype=float32)], val loss: 0.052770551294088364
# 	 partial train loss (single batch): 0.053494
# Epoch 335/3500 train loss: [array(0.05349444, dtype=float32)], val loss: 0.0541897714138031
# 	 partial train loss (single batch): 0.052895
# Epoch 336/3500 train loss: [array(0.05289484, dtype=float32)], val loss: 0.052824974060058594
# 	 partial train loss (single batch): 0.052653
# Epoch 337/3500 train loss: [array(0.0526533, dtype=float32)], val loss: 0.05130045861005783
# 	 partial train loss (single batch): 0.053186
# Epoch 338/3500 train loss: [array(0.05318604, dtype=float32)], val loss: 0.0528629906475544
# 	 partial train loss (single batch): 0.053127
# Epoch 339/3500 train loss: [array(0.0531271, dtype=float32)], val loss: 0.05110117793083191
# 	 partial train loss (single batch): 0.051840
# Epoch 340/3500 train loss: [array(0.05184019, dtype=float32)], val loss: 0.05234961956739426
# 	 partial train loss (single batch): 0.052697
# Epoch 341/3500 train loss: [array(0.05269743, dtype=float32)], val loss: 0.051918771117925644
# 	 partial train loss (single batch): 0.051634
# Epoch 342/3500 train loss: [array(0.05163441, dtype=float32)], val loss: 0.05203849449753761
# 	 partial train loss (single batch): 0.051830
# Epoch 343/3500 train loss: [array(0.05183003, dtype=float32)], val loss: 0.05259137228131294
# 	 partial train loss (single batch): 0.051617
# Epoch 344/3500 train loss: [array(0.05161659, dtype=float32)], val loss: 0.05231676623225212
# 	 partial train loss (single batch): 0.052543
# Epoch 345/3500 train loss: [array(0.05254299, dtype=float32)], val loss: 0.05160325765609741
# 	 partial train loss (single batch): 0.051097
# Epoch 346/3500 train loss: [array(0.05109666, dtype=float32)], val loss: 0.050337351858615875
# 	 partial train loss (single batch): 0.052893
# ...
# Epoch 3387/3500 train loss: [array(0.02691817, dtype=float32)], val loss: 0.02831130661070347
# 	 partial train loss (single batch): 0.026230
# Epoch 3388/3500 train loss: [array(0.02623023, dtype=float32)], val loss: 0.029230188578367233
# 	 partial train loss (single batch): 0.028071
# Epoch 3389/3500 train loss: [array(0.02807136, dtype=float32)], val loss: 0.028638100251555443
# 	 partial train loss (single batch): 0.027828
# Epoch 3390/3500 train loss: [array(0.02782807, dtype=float32)], val loss: 0.028207898139953613
# 	 partial train loss (single batch): 0.029113
# Epoch 3391/3500 train loss: [array(0.02911252, dtype=float32)], val loss: 0.02765602059662342
# 	 partial train loss (single batch): 0.029826
# Epoch 3392/3500 train loss: [array(0.02982597, dtype=float32)], val loss: 0.029330594465136528
# 	 partial train loss (single batch): 0.028372
# Epoch 3393/3500 train loss: [array(0.02837233, dtype=float32)], val loss: 0.028805367648601532
# 	 partial train loss (single batch): 0.028016
# Epoch 3394/3500 train loss: [array(0.02801642, dtype=float32)], val loss: 0.028219090774655342
# 	 partial train loss (single batch): 0.028437
# Epoch 3395/3500 train loss: [array(0.02843731, dtype=float32)], val loss: 0.028513621538877487
# 	 partial train loss (single batch): 0.028513
# Epoch 3396/3500 train loss: [array(0.02851277, dtype=float32)], val loss: 0.0291603971272707
# 	 partial train loss (single batch): 0.028264
# Epoch 3397/3500 train loss: [array(0.02826449, dtype=float32)], val loss: 0.027682015672326088
# 	 partial train loss (single batch): 0.031607
# Epoch 3398/3500 train loss: [array(0.03160737, dtype=float32)], val loss: 0.02740454114973545
# 	 partial train loss (single batch): 0.027878
# Epoch 3399/3500 train loss: [array(0.02787754, dtype=float32)], val loss: 0.029280342161655426
# 	 partial train loss (single batch): 0.027766
# Epoch 3400/3500 train loss: [array(0.02776626, dtype=float32)], val loss: 0.028366034850478172
# 	 partial train loss (single batch): 0.030043
# Epoch 3401/3500 train loss: [array(0.0300433, dtype=float32)], val loss: 0.02842179872095585
# 	 partial train loss (single batch): 0.028428
# Epoch 3402/3500 train loss: [array(0.02842752, dtype=float32)], val loss: 0.029058972373604774
# 	 partial train loss (single batch): 0.029025
# Epoch 3403/3500 train loss: [array(0.02902479, dtype=float32)], val loss: 0.028478335589170456
# 	 partial train loss (single batch): 0.028062
# Epoch 3404/3500 train loss: [array(0.02806201, dtype=float32)], val loss: 0.02815086953341961
# 	 partial train loss (single batch): 0.028019
# Epoch 3405/3500 train loss: [array(0.02801926, dtype=float32)], val loss: 0.02635069005191326
# 	 partial train loss (single batch): 0.028175
# Epoch 3406/3500 train loss: [array(0.02817519, dtype=float32)], val loss: 0.027820101007819176
# 	 partial train loss (single batch): 0.029486
# Epoch 3407/3500 train loss: [array(0.02948621, dtype=float32)], val loss: 0.029151858761906624
# 	 partial train loss (single batch): 0.029014
# Epoch 3408/3500 train loss: [array(0.02901419, dtype=float32)], val loss: 0.028283892199397087
# 	 partial train loss (single batch): 0.028812
# Epoch 3409/3500 train loss: [array(0.0288115, dtype=float32)], val loss: 0.028481094166636467
# 	 partial train loss (single batch): 0.028533
# Epoch 3410/3500 train loss: [array(0.02853313, dtype=float32)], val loss: 0.027900656685233116
# 	 partial train loss (single batch): 0.028145
# Epoch 3411/3500 train loss: [array(0.02814453, dtype=float32)], val loss: 0.0270929466933012
# 	 partial train loss (single batch): 0.028714
# Epoch 3412/3500 train loss: [array(0.02871432, dtype=float32)], val loss: 0.029061589390039444
# 	 partial train loss (single batch): 0.028143
# Epoch 3413/3500 train loss: [array(0.02814264, dtype=float32)], val loss: 0.028988370671868324
# 	 partial train loss (single batch): 0.027755
# Epoch 3414/3500 train loss: [array(0.02775536, dtype=float32)], val loss: 0.02906952053308487
# 	 partial train loss (single batch): 0.027706
# Epoch 3415/3500 train loss: [array(0.02770616, dtype=float32)], val loss: 0.027411041781306267
# 	 partial train loss (single batch): 0.028086
# Epoch 3416/3500 train loss: [array(0.02808631, dtype=float32)], val loss: 0.026920851320028305
# 	 partial train loss (single batch): 0.028572
# Epoch 3417/3500 train loss: [array(0.02857187, dtype=float32)], val loss: 0.02792469598352909
# 	 partial train loss (single batch): 0.028563
# Epoch 3418/3500 train loss: [array(0.0285633, dtype=float32)], val loss: 0.027186261489987373
# 	 partial train loss (single batch): 0.026629
# Epoch 3419/3500 train loss: [array(0.02662918, dtype=float32)], val loss: 0.02644733525812626
# 	 partial train loss (single batch): 0.026669
# Epoch 3420/3500 train loss: [array(0.02666902, dtype=float32)], val loss: 0.02917109616100788
# 	 partial train loss (single batch): 0.027588
# Epoch 3421/3500 train loss: [array(0.02758792, dtype=float32)], val loss: 0.027925625443458557
# 	 partial train loss (single batch): 0.029090
# Epoch 3422/3500 train loss: [array(0.02908963, dtype=float32)], val loss: 0.028883760794997215
# 	 partial train loss (single batch): 0.026749
# Epoch 3423/3500 train loss: [array(0.02674876, dtype=float32)], val loss: 0.028751112520694733
# 	 partial train loss (single batch): 0.027460
# Epoch 3424/3500 train loss: [array(0.02745959, dtype=float32)], val loss: 0.02687000297009945
# 	 partial train loss (single batch): 0.028301
# Epoch 3425/3500 train loss: [array(0.02830058, dtype=float32)], val loss: 0.02818281017243862
# 	 partial train loss (single batch): 0.030165
# Epoch 3426/3500 train loss: [array(0.03016531, dtype=float32)], val loss: 0.028323477134108543
# 	 partial train loss (single batch): 0.029155
# Epoch 3427/3500 train loss: [array(0.0291551, dtype=float32)], val loss: 0.028623327612876892
# 	 partial train loss (single batch): 0.027746
# Epoch 3428/3500 train loss: [array(0.0277458, dtype=float32)], val loss: 0.029559599235653877
# 	 partial train loss (single batch): 0.027254
# Epoch 3429/3500 train loss: [array(0.02725443, dtype=float32)], val loss: 0.028278332203626633
# 	 partial train loss (single batch): 0.027257
# Epoch 3430/3500 train loss: [array(0.02725717, dtype=float32)], val loss: 0.028536150231957436
# 	 partial train loss (single batch): 0.027001
# Epoch 3431/3500 train loss: [array(0.02700121, dtype=float32)], val loss: 0.02683425508439541
# 	 partial train loss (single batch): 0.027713
# Epoch 3432/3500 train loss: [array(0.02771302, dtype=float32)], val loss: 0.02826104313135147
# 	 partial train loss (single batch): 0.026837
# Epoch 3433/3500 train loss: [array(0.02683712, dtype=float32)], val loss: 0.02914327196776867
# 	 partial train loss (single batch): 0.028389
# Epoch 3434/3500 train loss: [array(0.02838924, dtype=float32)], val loss: 0.02672910876572132
# 	 partial train loss (single batch): 0.027882
# Epoch 3435/3500 train loss: [array(0.0278818, dtype=float32)], val loss: 0.028145652264356613
# 	 partial train loss (single batch): 0.027152
# Epoch 3436/3500 train loss: [array(0.02715174, dtype=float32)], val loss: 0.02631072886288166
# 	 partial train loss (single batch): 0.028804
# Epoch 3437/3500 train loss: [array(0.02880383, dtype=float32)], val loss: 0.028046967461705208
# 	 partial train loss (single batch): 0.027658
# Epoch 3438/3500 train loss: [array(0.02765764, dtype=float32)], val loss: 0.02769174799323082
# 	 partial train loss (single batch): 0.028514
# Epoch 3439/3500 train loss: [array(0.02851396, dtype=float32)], val loss: 0.02690378576517105
# 	 partial train loss (single batch): 0.027289
# Epoch 3440/3500 train loss: [array(0.02728866, dtype=float32)], val loss: 0.028862150385975838
# 	 partial train loss (single batch): 0.027955
# Epoch 3441/3500 train loss: [array(0.02795538, dtype=float32)], val loss: 0.028984054923057556
# 	 partial train loss (single batch): 0.027448
# Epoch 3442/3500 train loss: [array(0.02744754, dtype=float32)], val loss: 0.028588436543941498
# 	 partial train loss (single batch): 0.029733
# Epoch 3443/3500 train loss: [array(0.02973273, dtype=float32)], val loss: 0.027340084314346313
# 	 partial train loss (single batch): 0.026934
# Epoch 3444/3500 train loss: [array(0.02693391, dtype=float32)], val loss: 0.025834709405899048
# 	 partial train loss (single batch): 0.028384
# Epoch 3445/3500 train loss: [array(0.02838413, dtype=float32)], val loss: 0.02857891470193863
# 	 partial train loss (single batch): 0.028386
# Epoch 3446/3500 train loss: [array(0.02838635, dtype=float32)], val loss: 0.028150558471679688
# 	 partial train loss (single batch): 0.030330
# Epoch 3447/3500 train loss: [array(0.03032993, dtype=float32)], val loss: 0.02829485572874546
# 	 partial train loss (single batch): 0.027699
# Epoch 3448/3500 train loss: [array(0.02769863, dtype=float32)], val loss: 0.027554035186767578
# 	 partial train loss (single batch): 0.028748
# Epoch 3449/3500 train loss: [array(0.02874755, dtype=float32)], val loss: 0.029324986040592194
# 	 partial train loss (single batch): 0.028380
# Epoch 3450/3500 train loss: [array(0.02837985, dtype=float32)], val loss: 0.02899337001144886
# 	 partial train loss (single batch): 0.027531
# Epoch 3451/3500 train loss: [array(0.02753077, dtype=float32)], val loss: 0.028120698407292366
# 	 partial train loss (single batch): 0.027253
# Epoch 3452/3500 train loss: [array(0.02725265, dtype=float32)], val loss: 0.029216909781098366
# 	 partial train loss (single batch): 0.029178
# Epoch 3453/3500 train loss: [array(0.02917837, dtype=float32)], val loss: 0.02584618516266346
# 	 partial train loss (single batch): 0.027843
# Epoch 3454/3500 train loss: [array(0.02784263, dtype=float32)], val loss: 0.028950100764632225
# 	 partial train loss (single batch): 0.029147
# Epoch 3455/3500 train loss: [array(0.02914745, dtype=float32)], val loss: 0.02639077603816986
# 	 partial train loss (single batch): 0.026054
# Epoch 3456/3500 train loss: [array(0.02605383, dtype=float32)], val loss: 0.02799368090927601
# 	 partial train loss (single batch): 0.027053
# Epoch 3457/3500 train loss: [array(0.02705318, dtype=float32)], val loss: 0.027153076604008675
# 	 partial train loss (single batch): 0.027735
# Epoch 3458/3500 train loss: [array(0.02773465, dtype=float32)], val loss: 0.026900699362158775
# 	 partial train loss (single batch): 0.027356
# Epoch 3459/3500 train loss: [array(0.02735627, dtype=float32)], val loss: 0.026936843991279602
# 	 partial train loss (single batch): 0.027754
# Epoch 3460/3500 train loss: [array(0.02775382, dtype=float32)], val loss: 0.027080604806542397
# 	 partial train loss (single batch): 0.026694
# Epoch 3461/3500 train loss: [array(0.02669409, dtype=float32)], val loss: 0.028412634506821632
# 	 partial train loss (single batch): 0.027840
# Epoch 3462/3500 train loss: [array(0.02784023, dtype=float32)], val loss: 0.02739533595740795
# 	 partial train loss (single batch): 0.027129
# Epoch 3463/3500 train loss: [array(0.02712895, dtype=float32)], val loss: 0.028477158397436142
# 	 partial train loss (single batch): 0.028521
# Epoch 3464/3500 train loss: [array(0.02852061, dtype=float32)], val loss: 0.02865665778517723
# 	 partial train loss (single batch): 0.026890
# Epoch 3465/3500 train loss: [array(0.02689038, dtype=float32)], val loss: 0.02897171676158905
# 	 partial train loss (single batch): 0.028858
# Epoch 3466/3500 train loss: [array(0.02885831, dtype=float32)], val loss: 0.028080107644200325
# 	 partial train loss (single batch): 0.027556
# Epoch 3467/3500 train loss: [array(0.02755582, dtype=float32)], val loss: 0.028640486299991608
# 	 partial train loss (single batch): 0.025611
# Epoch 3468/3500 train loss: [array(0.02561065, dtype=float32)], val loss: 0.02641911804676056
# 	 partial train loss (single batch): 0.027023
# Epoch 3469/3500 train loss: [array(0.02702328, dtype=float32)], val loss: 0.02805553376674652
# 	 partial train loss (single batch): 0.027093
# Epoch 3470/3500 train loss: [array(0.02709306, dtype=float32)], val loss: 0.02845991589128971
# 	 partial train loss (single batch): 0.029572
# Epoch 3471/3500 train loss: [array(0.0295718, dtype=float32)], val loss: 0.02729361690580845
# 	 partial train loss (single batch): 0.028766
# Epoch 3472/3500 train loss: [array(0.02876554, dtype=float32)], val loss: 0.028088388964533806
# 	 partial train loss (single batch): 0.028327
# Epoch 3473/3500 train loss: [array(0.02832658, dtype=float32)], val loss: 0.02750072255730629
# 	 partial train loss (single batch): 0.027263
# Epoch 3474/3500 train loss: [array(0.02726302, dtype=float32)], val loss: 0.029447568580508232
# 	 partial train loss (single batch): 0.027931
# Epoch 3475/3500 train loss: [array(0.02793147, dtype=float32)], val loss: 0.02864726446568966
# 	 partial train loss (single batch): 0.026561
# Epoch 3476/3500 train loss: [array(0.02656055, dtype=float32)], val loss: 0.02955307811498642
# 	 partial train loss (single batch): 0.029825
# Epoch 3477/3500 train loss: [array(0.02982473, dtype=float32)], val loss: 0.028611792251467705
# 	 partial train loss (single batch): 0.028088
# Epoch 3478/3500 train loss: [array(0.02808808, dtype=float32)], val loss: 0.028087632730603218
# 	 partial train loss (single batch): 0.026643
# Epoch 3479/3500 train loss: [array(0.0266433, dtype=float32)], val loss: 0.02822788432240486
# 	 partial train loss (single batch): 0.027537
# Epoch 3480/3500 train loss: [array(0.02753714, dtype=float32)], val loss: 0.028211548924446106
# 	 partial train loss (single batch): 0.029390
# Epoch 3481/3500 train loss: [array(0.02939023, dtype=float32)], val loss: 0.027373896911740303
# 	 partial train loss (single batch): 0.027806
# Epoch 3482/3500 train loss: [array(0.02780628, dtype=float32)], val loss: 0.028933340683579445
# 	 partial train loss (single batch): 0.027835
# Epoch 3483/3500 train loss: [array(0.02783535, dtype=float32)], val loss: 0.026888102293014526
# 	 partial train loss (single batch): 0.028304
# Epoch 3484/3500 train loss: [array(0.02830401, dtype=float32)], val loss: 0.030339311808347702
# 	 partial train loss (single batch): 0.027607
# Epoch 3485/3500 train loss: [array(0.02760721, dtype=float32)], val loss: 0.026662930846214294
# 	 partial train loss (single batch): 0.027689
# Epoch 3486/3500 train loss: [array(0.027689, dtype=float32)], val loss: 0.028203438967466354
# 	 partial train loss (single batch): 0.028771
# Epoch 3487/3500 train loss: [array(0.02877052, dtype=float32)], val loss: 0.028781350702047348
# 	 partial train loss (single batch): 0.028730
# Epoch 3488/3500 train loss: [array(0.02873044, dtype=float32)], val loss: 0.02849079854786396
# 	 partial train loss (single batch): 0.026957
# Epoch 3489/3500 train loss: [array(0.02695725, dtype=float32)], val loss: 0.02777590975165367
# 	 partial train loss (single batch): 0.029297
# Epoch 3490/3500 train loss: [array(0.02929742, dtype=float32)], val loss: 0.028816184028983116
# 	 partial train loss (single batch): 0.027755
# Epoch 3491/3500 train loss: [array(0.02775516, dtype=float32)], val loss: 0.026378393173217773
# 	 partial train loss (single batch): 0.027956
# Epoch 3492/3500 train loss: [array(0.02795565, dtype=float32)], val loss: 0.028384575620293617
# 	 partial train loss (single batch): 0.027764
# Epoch 3493/3500 train loss: [array(0.02776388, dtype=float32)], val loss: 0.028216876089572906
# 	 partial train loss (single batch): 0.029415
# Epoch 3494/3500 train loss: [array(0.02941549, dtype=float32)], val loss: 0.02839728258550167
# 	 partial train loss (single batch): 0.027755
# Epoch 3495/3500 train loss: [array(0.02775516, dtype=float32)], val loss: 0.027390727773308754
# 	 partial train loss (single batch): 0.027733
# Epoch 3496/3500 train loss: [array(0.02773272, dtype=float32)], val loss: 0.029225820675492287
# 	 partial train loss (single batch): 0.027482
# Epoch 3497/3500 train loss: [array(0.02748178, dtype=float32)], val loss: 0.02743576467037201
# 	 partial train loss (single batch): 0.029053
# Epoch 3498/3500 train loss: [array(0.02905275, dtype=float32)], val loss: 0.028637340292334557
# 	 partial train loss (single batch): 0.028863
# Epoch 3499/3500 train loss: [array(0.02886296, dtype=float32)], val loss: 0.028775811195373535
# 	 partial train loss (single batch): 0.027879
# Epoch 3500/3500 train loss: [array(0.02787941, dtype=float32)], val loss: 0.029462773352861404

# %%
plt.figure(figsize=(10,8))
plt.semilogy(history['train_loss'], label='Train')
plt.semilogy(history['val_loss'], label='Valid')
plt.xlabel('Epoch')
plt.ylabel('Average Loss')
#plt.grid()
plt.legend()
#plt.title('loss')
plt.show()

# %%
z = np.random.randn(100, 8)
z = torch.Tensor(z)
with torch.no_grad():
    x_hat = decoder(z)
plt.imshow(np.array(x_hat[8]).reshape((28, 28)))

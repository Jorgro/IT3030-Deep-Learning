# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import seaborn as sns
import settings

# %%
df_train = pd.read_csv("./data/no1_train.csv")
df_train.describe()
# Out:
#                hydro          micro        thermal           wind     river  \
# count  225088.000000  225088.000000  225088.000000  225088.000000  225088.0
# mean     1888.334127     224.189826      21.803497      55.703266       0.0
# std       401.000305      58.559855       3.579229      47.053033       0.0
# min       683.438000      80.371000       0.000000       0.000000       0.0
# 25%      1625.029000     185.017000      22.100000      15.704000       0.0
# 50%      1933.916000     225.938000      22.100000      41.848000       0.0
# 75%      2175.595000     269.558000      24.100000      88.723000       0.0
# max      2995.524000     349.271000      25.700000     176.000000       0.0
#
#                total              y        sys_reg           flow
# count  225088.000000  225088.000000  225088.000000  225088.000000
# mean     2190.031963       8.907921      -8.284305   -1999.055081
# std       444.077730     320.262539      43.748315    1311.682286
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# Lets plot all the columns the original dataframe.

# %% [markdown]
# ### y: Power imbalance

# %%
sns.lineplot(data=df_train, x=df_train.index, y='y')
# Out:
# <AxesSubplot:ylabel='y'>

# %% [markdown]
# We can see some very high high peeks here which can cause some problems.

# %% [markdown]
# ### Hydro

# %%
sns.lineplot(data=df_train, x=df_train.index, y='hydro')
# Out:
# <AxesSubplot:ylabel='hydro'>

# %% [markdown]
# Nothing special here.

# %% [markdown]
# ### Micro (small-scale hydro power)

# %%
sns.lineplot(data=df_train, x=df_train.index, y='micro')
# Out:
# <AxesSubplot:ylabel='micro'>

# %% [markdown]
# Nothing special here.

# %% [markdown]
# ### Thermal

# %%
sns.lineplot(data=df_train, x=df_train.index, y='hydro')
# Out:
# <AxesSubplot:ylabel='hydro'>

# %% [markdown]
# Nothing special here.

# %% [markdown]
# ### Wind

# %%
sns.lineplot(data=df_train, x=df_train.index, y='wind')
# Out:
# <AxesSubplot:ylabel='wind'>

# %% [markdown]
# Lot of variance here, but nothing very special.

# %% [markdown]
# ### River

# %%
sns.lineplot(data=df_train, x=df_train.index, y='river')
# Out:
# <AxesSubplot:ylabel='river'>

# %% [markdown]
# Looks like this column is missing its data. We will drop it later on.

# %% [markdown]
# ### Total power production

# %%
sns.lineplot(data=df_train, x=df_train.index, y='total')
# Out:
# <AxesSubplot:ylabel='total'>

# %% [markdown]
# Looks fine.

# %% [markdown]
# ### System regulation

# %%
sns.lineplot(data=df_train, x=df_train.index, y='sys_reg')
# Out:
# <AxesSubplot:ylabel='sys_reg'>

# %% [markdown]
# Lots of sudden jumps here, but looks fine.

# %% [markdown]
# ## Correlation matrix

# %%
corrmat = df_train.corr()
sns.heatmap(corrmat, vmax=0.8, square=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see here that flow has a small negative correlation with y, while system regulation has a very high correlation with y.
